# %% [markdown]
# # Financial Market A/B Testing Dataset

# %% [markdown]
# Comprehensive Dataset Explanation
#
# Task: Analyze and Optimize Market Strategies Through Experiments
#
# This dataset is designed to facilitate A/B testing in the financial market context. It allows users to simulate, analyze, and optimize market strategies by comparing the performance of control and treatment groups under various trading scenarios.

# %% [raw]
# Key Features:
# Control and Treatment Groups:
#
# The control group represents baseline market behavior.
# The treatment group reflects the impact of a specific trading strategy or market intervention.
# Market Variables:
#
# Includes features like price fluctuations, trading volume, market sentiment, and external indicators.
# Outcome Metrics:
#
# Metrics include profitability, win rates, and other success indicators for evaluating strategies.
# Versatility:
#
# Ideal for experiments such as testing algorithmic trading strategies, market sentiment analysis, and behavioral finance studies.
# Use Cases:
# Assessing the effectiveness of new trading algorithms.
# Understanding the impact of market volatility on trading outcomes.
# Conducting simulations for educational and research purposes in finance.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
df = pd.read_csv('financial_market_ab_test.csv')
df.head()
# Out:
#     ticker        date  price_before  price_after  volume_before  \
# 0  EUR/USD  2023-01-02   1871.024737  1461.014437         359710
# 1  BTC/USD  2023-01-03   1173.753049   236.960238         386893
# 2     AMZN  2023-01-04   1423.636565   235.387783         124765
# 3  BTC/USD  2023-01-05   1852.748824   123.006103         388025
# 4  BTC/USD  2023-01-06   1443.753405  1917.352657         949377
#
#    volume_after strategy_version market_condition  return_before  \
# 0        777505                B          Bullish      -0.061653
# 1        953164                B          Bearish       0.011099
# 2        332119                B          Bullish       0.016784
# 3        164244                B          Bearish      -0.058601
# 4        453413                A          Bearish       0.070281
#
#    return_after    target
# 0      0.007305  0.068958
# 1      0.071988  0.060889
# 2     -0.057393 -0.074177
# 3      0.021556  0.080157
# 4     -0.083242 -0.153523

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ticker            1000 non-null   object
#  1   date              1000 non-null   object
#  2   price_before      1000 non-null   float64
#  3   price_after       1000 non-null   float64
#  4   volume_before     1000 non-null   int64
#  5   volume_after      1000 non-null   int64
#  6   strategy_version  1000 non-null   object
#  7   market_condition  1000 non-null   object
#  8   return_before     1000 non-null   float64
#  9   return_after      1000 non-null   float64
#  10  target            1000 non-null   float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 86.1+ KB

# %%
# Average profit

df["profit"] = df["return_after"] - df["return_before"]
df["profit"].head()
# Out:
# 0    0.068958
# 1    0.060889
# 2   -0.074177
# 3    0.080157
# 4   -0.153523
# Name: profit, dtype: float64

# %%
avg_profit = df.groupby("strategy_version")["profit"].agg(['mean', 'median', 'std', 'count']). reset_index()

# %%
print(avg_profit)
# Out:
#   strategy_version      mean    median       std  count
# 0                A -0.003031 -0.002728  0.082916    483
# 1                B  0.008523  0.011060  0.082307    517

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.isna().sum()
# Out:
# ticker              0
# date                0
# price_before        0
# price_after         0
# volume_before       0
# volume_after        0
# strategy_version    0
# market_condition    0
# return_before       0
# return_after        0
# target              0
# profit              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
avg_mean_profit = df.groupby("strategy_version")["profit"].mean()

# %%
plt.figure()
plt.bar(avg_mean_profit.index, avg_mean_profit.values)

plt.xlabel("Strategy")
plt.ylabel("Average Profit")
plt.title("Average profit b/w A and B")
plt.show()

# %%
stats = df.groupby("strategy_version")["profit"].agg(["mean", "std"])

# %%
plt.figure()
plt.bar(stats.index, stats["mean"], yerr=stats["std"])

plt.xlabel("Strategy")
plt.ylabel("Average Profit")
plt.title("Average profit with variabliity")
plt.show()

# %%
sns.boxplot(x='strategy_version', y='return_after', data=df)
plt.title('Post-Trade Return by Strategy')
plt.show()

sns.boxplot(x='market_condition', y='return_after', data=df)
plt.title('Post-Trade Return by Market Condition')
plt.show()

# %%
df.tail()
# Out:
#       ticker        date  price_before  price_after  volume_before  \
# 995    GOOGL  2026-10-26   1501.124161  1964.173090         246144
# 996     AAPL  2026-10-27   1073.221650  1182.125581         879499
# 997     AAPL  2026-10-28   1392.432780   593.129388         677999
# 998  EUR/USD  2026-10-29    179.178511   930.292183         196784
# 999     AMZN  2026-10-30    261.104830  1227.765777         935137
#
#      volume_after strategy_version market_condition  return_before  \
# 995        149441                A         Sideways      -0.074884
# 996        143867                B          Bearish       0.053109
# 997         71021                A          Bearish      -0.057962
# 998        370349                B          Bullish      -0.035311
# 999        462370                B         Sideways       0.063847
#
#      return_after    target    profit
# 995     -0.019102  0.055782  0.055782
# 996     -0.008875 -0.061984 -0.061984
# 997      0.041152  0.099113  0.099113
# ...

# %%
df.describe()
# Out:
#        price_before  price_after  volume_before   volume_after  return_before  \
# count   1000.000000  1000.000000    1000.000000    1000.000000    1000.000000
# mean    1050.464151  1046.948389  496237.225000  517045.527000      -0.002686
# std      556.165184   548.718460  284876.038329  282563.076918       0.058713
# min      108.800844   100.255917    3187.000000    1917.000000      -0.099850
# 25%      547.826899   593.646942  265193.750000  275485.250000      -0.053926
# 50%     1058.272542  1048.723987  484448.500000  502749.000000      -0.004915
# 75%     1515.583885  1527.331884  743872.000000  770801.000000       0.048517
# max     1998.886079  1996.860272  999555.000000  998159.000000       0.099810
#
#        return_after       target       profit
# count   1000.000000  1000.000000  1000.000000
# mean       0.000257     0.002943     0.002943
# std        0.056566     0.082762     0.082762
# min       -0.099874    -0.199067    -0.199067
# ...

# %%
from scipy.stats import ttest_ind
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.cluster import KMeans

# %%
sns.histplot(df["profit"], bins=30, kde=True, color= 'darkseagreen')
# Out:
# <Axes: xlabel='profit', ylabel='Count'>

# %%
plt.hist(df["profit"], bins=30)
plt.title("Profit Distribution")
plt.show()

# %%
from scipy.stats import shapiro
shapiro(df["profit"])
# Out:
# ShapiroResult(statistic=0.9923109228100767, pvalue=4.616414217513733e-05)

# %%
df["profit"].skew()
# Out:
# -0.05221969975641673

# %%
le = LabelEncoder()
df['strategy_num'] = le.fit_transform(df['strategy_version'])
df['ticker_num'] = le.fit_transform(df['ticker'])
df['market_num'] = le.fit_transform(df['market_condition'])

df['price_change'] = df['price_after'] - df['price_before']
df['volume_change'] = df['volume_after'] - df['volume_before']
df['return_diff'] = df['return_after'] - df['return_before']
df['is_profit'] = (df['return_after'] > 0).astype(int)

feature_cols = [
    'strategy_num', 'ticker_num', 'market_num',
    'price_change', 'volume_change', 'return_before', 'return_after', 'return_diff'
]
df[feature_cols].describe()
# Out:
#        strategy_num   ticker_num   market_num  price_change  volume_change  \
# count   1000.000000  1000.000000  1000.000000   1000.000000     1000.00000
# mean       0.517000     1.976000     0.997000     -3.515762    20808.30200
# std        0.499961     1.413302     0.818328    769.172352   397550.08591
# min        0.000000     0.000000     0.000000  -1757.528129  -905514.00000
# 25%        0.000000     1.000000     0.000000   -583.777023  -248491.25000
# 50%        1.000000     2.000000     1.000000    -10.526108    16799.00000
# 75%        1.000000     3.000000     2.000000    592.191468   304888.75000
# max        1.000000     4.000000     2.000000   1815.150805   971880.00000
#
#        return_before  return_after  return_diff
# count    1000.000000   1000.000000  1000.000000
# mean       -0.002686      0.000257     0.002943
# std         0.058713      0.056566     0.082762
# min        -0.099850     -0.099874    -0.199067
# 25%        -0.053926     -0.046760    -0.056335
# ...

# %%
plt.figure(figsize=(10,8))
corr = df[feature_cols + ['is_profit']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
plt.scatter(df['profit'], df['return_after'])
plt.show()

# %%
teamA = df[df['strategy_version'] == 'A']['return_after']
teamB = df[df['strategy_version'] == 'B']['return_after']
t_stat, p_val = ttest_ind(teamA, teamB, equal_var=False)
print(f"T-test Team A vs B: t = {t_stat:.3f}, p = {p_val:.3f}")
print("Significant difference" if p_val < 0.05 else "No significant difference")
# Out:
# T-test Team A vs B: t = -1.759, p = 0.079
# No significant difference

# %%
import statsmodels.api as sm

# %%
X_withconstant = sm.add_constant(df[['strategy_num', 'market_num', 'ticker_num', 'price_change', 'volume_change']])

# %%
# 1. Instantiate Model
myregression = sm.OLS(df['return_after'], X_withconstant)

# 2. Fit Model (this returns a seperate object with the parameters)
myregression_results = myregression.fit()

# Looking at the summary
myregression_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           return_after   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9392
# Date:                Sun, 22 Feb 2026   Prob (F-statistic):              0.455
# Time:                        16:27:48   Log-Likelihood:                 1456.3
# No. Observations:                1000   AIC:                            -2901.
# Df Residuals:                     994   BIC:                            -2871.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
X_l = df[feature_cols]
y_l = df['is_profit']

scaler = StandardScaler()
X_scale = scaler.fit_transform(X_l)
logreg = LogisticRegression()
logreg.fit(X_scale, y_l)

y_pred = logreg.predict(X_scale)
print(classification_report(y_l, y_pred))
print("ROC AUC:", roc_auc_score(y_l, logreg.predict_proba(X_scale)[:,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       486
#            1       0.98      1.00      0.99       514
#
#     accuracy                           0.99      1000
#    macro avg       0.99      0.99      0.99      1000
# weighted avg       0.99      0.99      0.99      1000
#
# ROC AUC: 0.9999079278154073

# %%
data = df['is_profit']

# %%
mean = np.mean(data)
stdv = np.std(data, ddof=1)
n = len(data)

# %%
import scipy.stats as stats

confidence = 0.95
t_critical = stats.t.ppf((1 + confidence) / 2, df=n-1)

margin_error = t_critical * (stdv / np.sqrt(n))

lower = mean - margin_error
upper = mean + margin_error

print(lower, upper)
# Out:
# 0.48296930305313984 0.5450306969468602

# %%
type(stats)
# Out:
# pandas.core.frame.DataFrame

# %%
(upper - lower)/2*100
# Out:
# 3.10306969468602

# %% [markdown]
# So the margin of error is 3.1%. It can be acceptable to the business.
